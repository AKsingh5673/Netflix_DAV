# %%
# This is a project on data analysis and visualisation with python on NETFLIX MOVIES AND SHOWS
# This project offers a comprehensive exploration of Netflix’s vast movie and show catalog, utilizing Python for data analysis and visualization to uncover important trends. It delves into the popularity of different genres, the proportion of movies versus TV series, and patterns in release dates over time. By examining regional viewing habits, the project reveals how Netflix tailors its content to suit diverse global audiences, providing a deeper understanding of how viewer preferences and content strategies have evolved in the ever-changing world of streaming.

# %%
from IPython.display import Image
Image(filename='image.jpg',width="800", height='50')

# %%
#importing required modules
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import cufflinks as cf 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
#some default settings
# %matplotlib inline
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
#data visualisation
data= pd.read_csv("NETFLIX dataset.csv")
data.head()
# Out:
#   show_id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  Date  Year Rating   Duration  \
# 0  September 25, 2021  2020  PG-13     90 min
# 1  September 24, 2021  2021  TV-MA  2 Seasons
# 2  September 24, 2021  2021  TV-MA   1 Season
# ...

# %%
data.tail()
# Out:
#    show_id     Type                                              Title  \
# 95     s96  TV Show                                         The Circle
# 96     s97    Movie  If I Leave Here Tomorrow: A Film About Lynyrd ...
# 97     s98  TV Show                                         Kid Cosmic
# 98     s99  TV Show                          Octonauts: Above & Beyond
# 99    s100  TV Show                                       On the Verge
#
#          Director                                               Cast  \
# 95            NaN                                    Michelle Buteau
# 96  Stephen Kijak  Ronnie Van Zandt, Gary Rossington, Allen Colli...
# 97            NaN  Jack Fisher, Tom Kenny, Amanda C. Miller, Kim ...
# 98            NaN  Antonio Aakeel, Chipo Chung, Simon Foster, Ter...
# 99            NaN  Julie Delpy, Elisabeth Shue, Sarah Jones, Alex...
#
#            Country               Date  Year Rating   Duration  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   show_id    100 non-null    object
#  1   Type       100 non-null    object
#  2   Title      100 non-null    object
#  3   Director   62 non-null     object
#  4   Cast       89 non-null     object
#  5   Country    91 non-null     object
#  6   Date       100 non-null    object
#  7   Year       100 non-null    int64
#  8   Rating     100 non-null    object
#  9   Duration   100 non-null    object
#  10  listed_in  100 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 8.7+ KB

# %%
data.describe().T
# Out:
#       count     mean        std     min     25%     50%     75%     max
# Year  100.0  2015.11  10.167183  1975.0  2013.0  2021.0  2021.0  2021.0

# %%
#Visualizing the null values using missingo function
import missingno as msno
msno.matrix(data)
# Out:
# <Axes: >

# %%
# visualising the number of Movies and TV Shows in the dataset
plt.subplots(figsize=(15,5))
data['Type'].value_counts(normalize = True)
data['Type'].value_counts(dropna = False).plot.bar(color = ['purple','blue'])
plt.title('Comparison of Movies and TV Shows')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
data['Country'].value_counts()
# Out:
# Country
#                            31
# United States              21
# Japan                      13
# India                       6
# United Kingdom              6
# Nigeria                     3
# China                       2
# South Africa                1
# Germany, Czech Republic     1
# Mexico                      1
# Turkey                      1
# Australia                   1
# Finland                     1
# Spain, United States        1
# France                      1
# Belgium                     1
# Name: count, dtype: int64

# %%
# visualizing the different Rating in the dataset
df = data.groupby('Country').size()
df.plot(kind='pie', subplots=True, figsize=(10, 8))
plt.title("Pie Chart of Country")
plt.ylabel("")
plt.show()

# %%
# visualizing the differnt Rating
import matplotlib.pyplot as plt
plt.subplots(figsize=(18,5))
data['Country'].value_counts(normalize = True)
data['Country'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green', 'blue', 'cyan'])
plt.title('Comparison of Rating')
plt.xlabel('DRating')
plt.ylabel('Count')
plt.show()

# %%
# visualizing the differnt Rating in pie chart
df = data.groupby('Rating').size()
df.plot(kind='pie', subplots=True, figsize=(10, 8))
plt.title("Pie Chart of Rating")
plt.ylabel("")
plt.show()

# %%
# visualizing the differnt Rating
import matplotlib.pyplot as plt
plt.subplots(figsize=(18,5))
data['Rating'].value_counts(normalize = True)
data['Rating'].value_counts(dropna = False).plot.bar(color=['black', 'red', 'green', 'blue', 'cyan'])
plt.title('Comparison of Rating')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
# visualizing comparision of Date
plt.subplots(figsize=(15,5))
data['Date'].value_counts(normalize = True)
data['Date'].value_counts(dropna = False).plot.bar(figsize = (18, 10), color = 'orange')
plt.title('Comparison of Released Date')
plt.xlabel('Date')
plt.ylabel('Count')
plt.show()

# %%
# visualizing comparision of Years
plt.subplots(figsize=(15,5))
data['Year'].value_counts(normalize = True)

data['Year'].value_counts(dropna = False).plot.bar(figsize = (18, 10), color = 'blue')
plt.title('Comparison of Years')
plt.xlabel('Years')
plt.ylabel('Count')
plt.show()

# %%
# visualizing comparision of Years in Histogram
plt.subplots(figsize=(15,5))
plt.hist(data['Year'], bins=20, color='cyan')
plt.title('Comparison of Years')
plt.xlabel('Years')
plt.ylabel('Count')
plt.show()

# %%
#Title:Data preprocessing
data.columns
# Out:
# Index(['show_id', 'Type', 'Title', 'Director', 'Cast', 'Country', 'Date',
#        'Year', 'Rating', 'Duration', 'listed_in'],
#       dtype='object')

# %%
print(f'The dataset contains {data.shape[0]} rows and {data.shape[1]} columns')
# Out:
# The dataset contains 100 rows and 11 columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   show_id    100 non-null    object
#  1   Type       100 non-null    object
#  2   Title      100 non-null    object
#  3   Director   62 non-null     object
#  4   Cast       89 non-null     object
#  5   Country    91 non-null     object
#  6   Date       100 non-null    object
#  7   Year       100 non-null    int64
#  8   Rating     100 non-null    object
#  9   Duration   100 non-null    object
#  10  listed_in  100 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 8.7+ KB

# %%
data.isna().sum()
# Out:
# show_id       0
# Type          0
# Title         0
# Director     38
# Cast         11
# Country       9
# Date          0
# Year          0
# Rating        0
# Duration      0
# listed_in     0
# dtype: int64

# %%
data.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
netflix=data.dropna()


print(f'The dataset contains {netflix.shape[0]} rows and {netflix.shape[1]} columns')
# Out:
# The dataset contains 55 rows and 11 columns

# %%
duplicate_values=data.duplicated().sum()
print(f'The data contains {duplicate_values} duplicate values')
# Out:
# The data contains 0 duplicate values

# %%
#Title: Exploratory data analysis
#Does Netflix have more Movies or TV Shows???

# %%
data['Type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
import matplotlib.pyplot as plt
percent = data['Type'].value_counts()
plt.figure(figsize=(8,8))
plt.pie(percent.values, labels = percent.index, autopct = '%.1f%%', startangle = 90, explode = [0.1, 0], colors = ['crimson', 'dimgrey'])
plt.legend()
plt.title('Does Netflix have more Movies or TV Shows?', fontsize=16)
plt.show()

# %%
#Title:Data modelling

# %%
x = data.drop(['Type'], axis='columns')
y = data[['Type']]
